# %%
# import dependencies
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# load data as dataFrame
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# get x and y from data
x = df.iloc[:,:-1]
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# split data (x and y) to train 80% and test 20%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=16)

# %%
# initialize the model
model = DecisionTreeClassifier(criterion='entropy',max_depth=5,min_samples_split=2)

# %%
# train the model
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
# prediction of our data
y_predict = model.predict(x_test)

# %%
# plot tree
tree.plot_tree(model, filled=True)
# Out:
# [Text(0.43125, 0.9166666666666666, 'x[1] <= 127.5\nentropy = 0.936\nsamples = 614\nvalue = [398, 216]'),
#  Text(0.15625, 0.75, 'x[5] <= 26.4\nentropy = 0.712\nsamples = 384\nvalue = [309, 75]'),
#  Text(0.05, 0.5833333333333334, 'x[1] <= 106.0\nentropy = 0.186\nsamples = 106\nvalue = [103, 3]'),
#  Text(0.025, 0.4166666666666667, 'entropy = 0.0\nsamples = 70\nvalue = [70, 0]'),
#  Text(0.075, 0.4166666666666667, 'x[5] <= 22.95\nentropy = 0.414\nsamples = 36\nvalue = [33, 3]'),
#  Text(0.05, 0.25, 'x[4] <= 49.0\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.025, 0.08333333333333333, 'entropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.075, 0.08333333333333333, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1, 0.25, 'entropy = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.2625, 0.5833333333333334, 'x[7] <= 28.5\nentropy = 0.825\nsamples = 278\nvalue = [206, 72]'),
#  Text(0.175, 0.4166666666666667, 'x[5] <= 30.95\nentropy = 0.586\nsamples = 142\nvalue = [122, 20]'),
#  Text(0.15, 0.25, 'entropy = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.2, 0.25, 'x[2] <= 37.0\nentropy = 0.714\nsamples = 102\nvalue = [82, 20]'),
#  Text(0.175, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.225, 0.08333333333333333, 'entropy = 0.68\nsamples = 100\nvalue = [82, 18]'),
#  Text(0.35, 0.4166666666666667, 'x[1] <= 101.5\nentropy = 0.96\nsamples = 136\nvalue = [84, 52]'),
#  Text(0.3, 0.25, 'x[6] <= 0.636\nentropy = 0.665\nsamples = 52\nvalue = [43, 9]'),
#  Text(0.275, 0.08333333333333333, 'entropy = 0.378\nsamples = 41\nvalue = [38, 3]'),
#  Text(0.325, 0.08333333333333333, 'entropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.4, 0.25, 'x[6] <= 0.2\nentropy = 1.0\nsamples = 84\nvalue = [41, 43]'),
#  Text(0.375, 0.08333333333333333, 'entropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.425, 0.08333333333333333, 'entropy = 0.985\nsamples = 70\nvalue = [30, 40]'),
#  Text(0.70625, 0.75, 'x[5] <= 29.95\nentropy = 0.963\nsamples = 230\nvalue = [89, 141]'),
#  Text(0.575, 0.5833333333333334, 'x[1] <= 145.0\nentropy = 0.907\nsamples = 59\nvalue = [40, 19]'),
#  Text(0.525, 0.4166666666666667, 'x[4] <= 121.5\nentropy = 0.65\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.5, 0.25, 'x[0] <= 4.5\nentropy = 0.852\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.475, 0.08333333333333333, 'entropy = 0.98\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.525, 0.08333333333333333, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.55, 0.25, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.625, 0.4166666666666667, 'x[7] <= 25.5\nentropy = 0.999\nsamples = 29\nvalue = [15, 14]'),
#  Text(0.6, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.65, 0.25, 'x[7] <= 59.0\nentropy = 0.99\nsamples = 25\nvalue = [11, 14]'),
#  Text(0.625, 0.08333333333333333, 'entropy = 0.918\nsamples = 21\nvalue = [7, 14]'),
#  Text(0.675, 0.08333333333333333, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8375, 0.5833333333333334, 'x[1] <= 154.5\nentropy = 0.864\nsamples = 171\nvalue = [49, 122]'),
#  Text(0.775, 0.4166666666666667, 'x[1] <= 152.5\nentropy = 0.975\nsamples = 91\nvalue = [37, 54]'),
#  Text(0.75, 0.25, 'x[5] <= 45.55\nentropy = 0.947\nsamples = 85\nvalue = [31, 54]'),
#  Text(0.725, 0.08333333333333333, 'entropy = 0.969\nsamples = 78\nvalue = [31, 47]'),
#  Text(0.775, 0.08333333333333333, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9, 0.4166666666666667, 'x[4] <= 629.5\nentropy = 0.61\nsamples = 80\nvalue = [12, 68]'),
#  Text(0.85, 0.25, 'x[6] <= 0.343\nentropy = 0.557\nsamples = 77\nvalue = [10, 67]'),
#  Text(0.825, 0.08333333333333333, 'entropy = 0.826\nsamples = 27\nvalue = [7, 20]'),
#  Text(0.875, 0.08333333333333333, 'entropy = 0.327\nsamples = 50\nvalue = [3, 47]'),
#  Text(0.95, 0.25, 'x[6] <= 0.412\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.925, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.975, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
# accuracy
print('accuracy: ',accuracy_score(y_test,y_predict))
# Out:
# accuracy:  0.7987012987012987

# %%
confusion_matrix =confusion_matrix(y_test, y_predict)
cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,)
cm_display.plot()
plt.show()
